# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
tt=pd.read_excel('titanic.excel.xlsx')

# %%
tt
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
Pclass_survived=tt.groupby(['Pclass'])['Survived']

# %%
tt.Pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
Pclass_survived.sum()
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
#multiple columns
NSA=tt.groupby(['Name'])['Survived','Class']

# %%
NSA.sum()
# Out:
#                                                Survived  Class
# Name
# Abbing, Mr. Anthony                                 0.0    3.0
# Abbott, Master. Eugene Joseph                       0.0    3.0
# Abbott, Mr. Rossmore Edward                         0.0    3.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    1.0    3.0
# Abelseth, Miss. Karen Marie                         0.0    3.0
# ...                                                 ...    ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       0.0    2.0
# van Billiard, Master. James William                 0.0    3.0
# van Billiard, Master. Walter John                   0.0    3.0
# van Billiard, Mr. Austin Blyler                     0.0    3.0
# van Melkebeke, Mr. Philemon                         0.0    3.0
#
# [1307 rows x 2 columns]

# %%
nn=tt.groupby(['Name_wiki'])['Class','Age_wiki']

# %%
nn.value_counts()
# Out:
# Name_wiki                              Class  Age_wiki
# Abbing, Mr. Anthony                    3.0    40.0        1
# Abbott, Mr. Eugene Joseph              3.0    14.0        1
# Abbott, Mr. Rossmore Edward            3.0    16.0        1
# Abbott, Mrs. Rhoda Mary (née Hunt)     3.0    39.0        1
# Abd al-Khaliq, Mr. Farid Qasim Husayn  3.0    18.0        1
#                                                          ..
# Čačić, Mr. Luka                        3.0    38.0        1
# Čor, Mr. Bartol                        3.0    35.0        1
# Čor, Mr. Ivan                          3.0    27.0        1
# Čor, Mr. Liudevit                      3.0    19.0        1
# Čulumović, Mr. Jeso                    3.0    17.0        1
# Length: 1302, dtype: int64

# %%
nn.sum()
# Out:
#                                        Class  Age_wiki
# Name_wiki
# Abbing, Mr. Anthony                      3.0      40.0
# Abbott, Mr. Eugene Joseph                3.0      14.0
# Abbott, Mr. Rossmore Edward              3.0      16.0
# Abbott, Mrs. Rhoda Mary (née Hunt)       3.0      39.0
# Abd al-Khaliq, Mr. Farid Qasim Husayn    3.0      18.0
# ...                                      ...       ...
# Čačić, Mr. Luka                          3.0      38.0
# Čor, Mr. Bartol                          3.0      35.0
# Čor, Mr. Ivan                            3.0      27.0
# Čor, Mr. Liudevit                        3.0      19.0
# Čulumović, Mr. Jeso                      3.0      17.0
#
# [1303 rows x 2 columns]

# %%
tt.groupby(['Name'])['Fare']
tt.sum()
# Out:
# PassengerId                                               857395
# Survived                                                   342.0
# Pclass                                                      3004
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                     31255.67
# SibSp                                                        653
# Parch                                                        504
# Fare                                                  43550.4869
# WikiId                                                  858729.0
# Age_wiki                                                38299.41
# Class                                                     2988.0
# dtype: object

# %%
hbf=tt.groupby(['Hometown'])

# %%
#multiple groups
nba=tt.groupby(['Name','Sex','Ticket'])['Pclass','Survived','Fare']
nba.sum()
# Out:
#                                                                     Pclass  \
# Name                                          Sex    Ticket
# Abbing, Mr. Anthony                           male   C.A. 5547           3
# Abbott, Master. Eugene Joseph                 male   C.A. 2673           3
# Abbott, Mr. Rossmore Edward                   male   C.A. 2673           3
# Abbott, Mrs. Stanton (Rosa Hunt)              female C.A. 2673           3
# Abelseth, Miss. Karen Marie                   female 348125              3
# ...                                                                    ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi) female SC/PARIS 2167       2
# van Billiard, Master. James William           male   A/5. 851            3
# van Billiard, Master. Walter John             male   A/5. 851            3
# van Billiard, Mr. Austin Blyler               male   A/5. 851            3
# van Melkebeke, Mr. Philemon                   male   345777              3
#
# ...

# %%
#multiple function
mm=tt.groupby(['Cabin'])['Fare'].agg('mean','median')

# %%
mm
# Out:
# Cabin
# A10    40.1250
# A11    27.7208
# A14    52.0000
# A16    39.6000
# A18    29.7000
#         ...
# F33    11.1250
# F38     7.7500
# F4     39.0000
# G6     14.2050
# T      35.5000
# Name: Fare, Length: 186, dtype: float64
