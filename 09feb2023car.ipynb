# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
car=pd.read_csv('Car_sales.csv')
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car.dropna(inplace=True)
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
car.Latest_Launch.unique()
# Out:
# array(['2/2/2012', '6/3/2011', '3/10/2011', '10/8/2011', '8/9/2011',
#        '2/27/2012', '1/29/2012', '4/4/2011', '11/2/2011', '9/3/2011',
#        '3/23/2012', '7/23/2011', '2/23/2012', '11/27/2011', '9/28/2011',
#        '8/17/2011', '3/19/2012', '5/24/2011', '12/22/2011', '10/23/2011',
#        '5/12/2012', '9/11/2011', '4/13/2012', '1/16/2012', '11/17/2011',
#        '6/6/2012', '10/6/2011', '5/8/2012', '12/12/2011', '7/1/2012',
#        '10/31/2011', '8/7/2011', '3/6/2012', '1/6/2012', '7/26/2012',
#        '11/25/2011', '9/1/2011', '3/31/2012', '1/31/2012', '8/20/2012',
#        '12/20/2011', '9/26/2011', '4/25/2012', '2/25/2012', '9/14/2012',
#        '1/14/2012', '8/16/2012', '10/21/2011', '5/20/2012', '3/21/2012',
#        '10/9/2012', '2/8/2012', '9/10/2012', '11/15/2011', '6/14/2012',
#        '4/15/2012', '3/4/2012', '10/5/2012', '12/10/2011', '7/9/2012',
#        '5/10/2012', '3/29/2012', '8/3/2012', '6/4/2012', '4/23/2012',
# ...

# %%
car['Latest_Launch']= pd.to_datetime(car.Latest_Launch)
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
car['year']=pd.DatetimeIndex(car.Latest_Launch).year
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car['month']=pd.DatetimeIndex(car.Latest_Launch).month

# %%
car['day']=pd.DatetimeIndex(car.Latest_Launch).day

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
car.Fuel_efficiency=car.Fuel_efficiency.astype(int)
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int32
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %%
car.month.replace({
    1:"JANUARY",
    2:"FEBRUARY",
    3:"MARCH",
    4:"APRIL",
    5:"MAY",
    6:"JUNE",
    7:"JULY",
    8:"AUGUST",
    9:"SEPTEMBER",
    10:"OCTOBER",
    11:"NOVEMBER",
    12:"DECEMBER"
    
},
inplace=True)

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# label

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
car["levehicle"]=le.fit_transform(car.Vehicle_type)
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car["lemanuf"]=le.fit_transform(car.Manufacturer)
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car["lemonth"]=le.fit_transform(car.month)

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
car.Power_perf_factor=car.Power_perf_factor.astype(int)

# %%
car
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# histogram

# %%
car.Horsepower.plot.hist(figsize=(6,3),cmap='brg');

# %%
car.Sales_in_thousands.plot.box(figsize=(4,3),cmap='gist_earth');

# %%
car.Horsepower.plot.box(figsize=(4,2),cmap='gist_earth');

# %%
car.plot.box(figsize=(22,4),subplots=True);

# %%
car.plot.hist(figsize=(6,18),subplots=True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # line chart

# %%
car.sort_values(by='__year_resale_value').plot.line('__year_resale_value','Price_in_thousands',figsize=(6,3),cmap='inferno');

# %% [markdown]
# # bar plot

# %%
car.Manufacturer.value_counts().plot.bar(figsize=(6,3),cmap='turbo_r');

# %%
car.sort_values(by='Price_in_thousands')[:20].plot.bar('Manufacturer','Price_in_thousands',figsize=(6,3));

# %% [markdown]
# # area chart

# %%
car.plot.area('Manufacturer','Price_in_thousands',figsize=(6,3),cmap='turbo_r');

# %% [markdown]
# # horizontal bar chart

# %%
 car.sort_values(by='Price_in_thousands')[:5].plot.barh('Model','Power_perf_factor',figsize=(6,4),cmap='inferno');

# %% [markdown]
# # scatter plot

# %%
car.sort_values(by='Price_in_thousands')[:5].plot.scatter('Model','Latest_Launch',figsize=(6,4));

# %% [markdown]
# # box plot

# %%
car.plot.box(figsize=(22,5));

# %% [markdown]
# # pie chart

# %%
car.sort_values(by='Engine_size',ascending=False)[:8].Engine_size.plot.pie();

# %%
car.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  ...  \
# 0               21.50          1.8       140.0      101.2   67.3  ...
# 1               28.40          3.2       225.0      108.1   70.3  ...
# 3               42.00          3.5       210.0      114.6   71.4  ...
# 4               23.99          1.8       150.0      102.6   68.2  ...
# 5               33.95          2.8       200.0      108.7   76.1  ...
#
# ...

# %% [markdown]
# # kde

# %%
car.plot.kde(figsize=(10,3.8));
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4680\1907095385.py in <module>
# ----> 1 car.plot.kde(figsize=(10,3.8));
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwargs)
#    1452             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1453         """
# -> 1454         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1455
#    1456     density = kde
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
car.plot.kde(figsize=(12,10),subplots=True);
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4680\2489234513.py in <module>
# ----> 1 car.plot.kde(figsize=(12,10),subplots=True);
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwargs)
#    1452             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1453         """
# -> 1454         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1455
#    1456     density = kde
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %% [markdown]
# # hexbin plot

# %%
car.plot.hexbin('Curb_weight','Fuel_capacity',gridsize=10,cmap='autumn');
